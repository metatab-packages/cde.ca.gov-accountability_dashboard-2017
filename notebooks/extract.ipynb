# %% [markdown]
# Handle short lines in the gradrate file by reading via Pandas

# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # California Accountability Model & School Dashboard
# `cde.ca.gov-accountability_dashboard-2017-1.2.1` Last Update: 2021-02-25T02:42:53
#
# _Datasets for the California school dashboard at https://www.caschooldashboard.org_
#
#
# ## Documentation Links
#
# * [California Accountability Model & School Dashboard](http://www.cde.ca.gov/ta/ac/cm/) Program page for the dashboard, datasets and reports.
# * [California School Dashboard](https://www.caschooldashboard.org) The California School Dashboard website.
#
#
#
# ## Contacts
#
# * **Origin** [California Department of Education](http://www.cde.ca.gov/)
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://www.civicknowledge.com)
#
# ## Resources
#
# * ** [ela38](http://www3.cde.ca.gov/researchfiles/cadashboard/eladownload2017s.txt)**. English Language Arts, Grades 3-8
# * ** [ela11](http://www3.cde.ca.gov/researchfiles/cadashboard/ela11download2017s.txt)**. English Language Arts, Grade 11
# * ** [math38](http://www3.cde.ca.gov/researchfiles/cadashboard/mathdownload2017s.txt)**. Math, Grades 3-8
# * ** [math11](http://www3.cde.ca.gov/researchfiles/cadashboard/math11download2017s.txt)**. Math, Grade 11
# * ** [collegecareer](http://www3.cde.ca.gov/researchfiles/cadashboard/ccidownload2017s.txt)**. College / Career Indicators
# * ** [susprate](http://www3.cde.ca.gov/researchfiles/cadashboard/suspdownload2017s.txt)**. Suspension Rate
# * ** [elaprog](http://www3.cde.ca.gov/researchfiles/cadashboard/elpidownload2017s.txt)**. English Language Arts Progress Indicators
# * ** [gradrate](notebooks/extract.ipynb)**.
#
# ## References
# <ul><li> <strong><a href="http://www3.cde.ca.gov/researchfiles/cadashboard/graddownload2017s.txt">gradrate_source</a></strong>. </li><ul>

# %%
gradrate = pkg.reference('gradrate_source').dataframe(sep='\t')
# Out:
#                   cds rtype studentgroup  currnumer  currdenom  currstatus  \
# 0       1100170112607     S           AA       22.0         25        88.0
# 1       1100170112607     S           AI        NaN          4         NaN
# 2       1100170112607     S          ALL       65.0         72        90.3
# 3       1100170112607     S           AS        NaN          2         NaN
# 4       1100170112607     S           EL       10.0         11        90.9
# ...               ...   ...          ...        ...        ...         ...
# 18036  58727695838305     S           MR       14.0         14       100.0
# 18037  58727695838305     S           PI        NaN          0         NaN
# 18038  58727695838305     S          SED       62.0         71        87.3
# 18039  58727695838305     S          SWD       11.0         13        84.6
# 18040  58727695838305     S           WH       83.0         91        91.2
#
#        priornumer  priordenom  priorstatus  change  ...  prioryear2_numer  \
# 0            78.0         103         75.7    12.3  ...              26.0
# 1             NaN           4          NaN     NaN  ...               NaN
# 2           136.0         185         73.5    16.8  ...              51.0
# 3             NaN           4          NaN     NaN  ...               NaN
# 4            19.0          31         61.3    29.6  ...               8.0
# ...           ...         ...          ...     ...  ...               ...
# 18036        47.0          48         97.9     2.1  ...              11.0
# 18037         NaN           7          NaN     NaN  ...               NaN
# 18038       198.0         212         93.4    -6.1  ...              76.0
# 18039        34.0          38         89.5    -4.9  ...              11.0
# 18040       254.0         260         97.7    -6.5  ...              80.0
#
#        prioryear2_denom  prioryear2_status  prioryear3_numer  \
# 0                  34.0               76.5              34.0
# 1                   1.0                NaN               NaN
# 2                  68.0               75.0              48.0
# 3                   2.0                NaN               NaN
# 4                  11.0               72.7               NaN
# ...                 ...                ...               ...
# 18036              11.0              100.0              22.0
# 18037               3.0                NaN               NaN
# 18038              78.0               97.4              56.0
# 18039              11.0              100.0               9.0
# 18040              82.0               97.6              77.0
#
#        prioryear3_denom  prioryear3_status  statuslevel  changelevel  color  \
# 0                    40               85.0          3.0          5.0    0.0
# 1                     1                NaN          0.0          0.0    0.0
# 2                    61               78.7          4.0          5.0    5.0
# 3                     2                NaN          0.0          0.0    0.0
# 4                     8                NaN          4.0          5.0    0.0
# ...                 ...                ...          ...          ...    ...
# 18036                23               95.7          5.0          4.0    0.0
# 18037                 3                NaN          0.0          0.0    0.0
# 18038                63               88.9          3.0          1.0    2.0
# 18039                11               81.8          2.0          2.0    0.0
# 18040                79               97.5          4.0          1.0    2.0
#
#          box
# 0        0.0
# 1        0.0
# 2      100.0
# 3        0.0
# 4        0.0
# ...      ...
# 18036    0.0
# 18037    0.0
# 18038  110.0
# 18039    0.0
# 18040   60.0
#
# [18041 rows x 23 columns]
